# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/smishingAI/MachineLearningDev/CombinedModels/1. MsgPredict
# Out:
# /content/drive/MyDrive/Colab Notebooks/smishingAI/MachineLearningDev/CombinedModels/1. MsgPredict

# %%
# !python msg_predict_main.py
# Out:
# Class distribution before balancing: Counter({0: 10158, 2: 1383, 1: 471})
# Class distribution after balancing: Counter({0: 10158, 1: 10158, 2: 10158})
#   0% 0/5 [00:00<?, ?it/s]
#
# Training model: Naive Bayes multinomial
# Best parameters for Naive Bayes multinomial: {'alpha': 0.1, 'fit_prior': False}
# Best grid search score for Naive Bayes multinomial: 0.8895451920459694
# Naive Bayes multinomial trained with best parameters!
# Accuracy on training data:     0.8941392662597624
# Accuracy on test data:         0.9393939393939394
# Balanced accuracy:             0.7707939596030772
# Precision:                     0.9460874970034178
# Recall:                        0.9393939393939394
# F1:                            0.9420736635831204
# Figure(1000x700)
# Training time: 1 seconds
# /content/drive/MyDrive/Colab Notebooks/smishingAI/MachineLearningDev/CombinedModels/1. MsgPredict/utils.py:455: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   rec.loc[len(rec.index)] = record
#  20% 1/5 [00:01<00:06,  1.62s/it]
#
# Training model: AdaBoost
# Best parameters for AdaBoost: {'n_estimators': 200}
# Best grid search score for AdaBoost: 0.7812891767019996
# AdaBoost trained with best parameters!
# Accuracy on training data:     0.7950055785259565
# Accuracy on test data:         0.9234654234654235
# Balanced accuracy:             0.7289509058484022
# Precision:                     0.9257171560626427
# Recall:                        0.9234654234654235
# F1:                            0.9245165450420049
# Figure(1000x700)
# Training time: 283 seconds
# /content/drive/MyDrive/Colab Notebooks/smishingAI/MachineLearningDev/CombinedModels/1. MsgPredict/utils.py:455: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   rec.loc[len(rec.index)] = record
#  40% 2/5 [04:44<08:21, 167.24s/it]
#
# Training model: Random Forest
